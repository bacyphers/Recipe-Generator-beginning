# %%
import pandas as pd
import ast 
import isodate
chicken_list=pd.read_csv('/Users/brockberenato/Desktop/capstone - individual overview/chicken_ing')
chicken_list
# Out:
#       RecipeId                                               Name CookTime  \
# 0         44.0                             Warm Chicken A La King     PT3M
# 1         71.0                              Chicken and Dumplings    PT43M
# 2        112.0                       Chicken and Broccoli Lasagna    PT55M
# 3        150.0                      All-Purpose Crock Pot Chicken  PT8H40M
# 4        162.0                                    Chicken Lasagna     PT2H
# ...        ...                                                ...      ...
# 5412  540829.0                    Homemade Tomato Soup (Low Carb)    PT30M
# 5413  540945.0                             Sichuan Pepper Chicken    PT20M
# 5414  541168.0                     D.A.M. Good Chicken Enchiladas    PT25M
# 5415  541329.0  Rhonda&rsquo;s Imitation Doan&rsquo;s Curry Ch...  PT3H30M
# 5416  541354.0           Chicken Pot Pie with Mashed Potato Crust     PT1H
#
#      PrepTime TotalTime RecipeCategory  \
# ...

# %%
chicken_list.CookTime
# Out:
# 0          PT3M
# 1         PT43M
# 2         PT55M
# 3       PT8H40M
# 4          PT2H
#          ...
# 5412      PT30M
# 5413      PT20M
# 5414      PT25M
# 5415    PT3H30M
# 5416       PT1H
# Name: CookTime, Length: 5417, dtype: object

# %%
#all cooktime
def strfdelta(tdelta, fmt):
    d = {"days": tdelta.days}
    d["hours"], rem = divmod(tdelta.seconds, 3600)
    d["minutes"], d["seconds"] = divmod(rem,60)
    day_in_hours= d["days"]*24
    d["hours"] = d["hours"] + day_in_hours
    return fmt.format(**d)
cook_time_list = chicken_list.loc[:, "CookTime"]
for i, cook_time in enumerate(chicken_list['CookTime']):
    new_cook_time = strfdelta(isodate.parse_duration(cook_time), '{hours}:{minutes}')
    chicken_list.at[i, 'CookTime'] = new_cook_time
chicken_list
# Out:
#       RecipeId                                               Name CookTime  \
# 0         44.0                             Warm Chicken A La King      0:3
# 1         71.0                              Chicken and Dumplings     0:43
# 2        112.0                       Chicken and Broccoli Lasagna     0:55
# 3        150.0                      All-Purpose Crock Pot Chicken     8:40
# 4        162.0                                    Chicken Lasagna      2:0
# ...        ...                                                ...      ...
# 5412  540829.0                    Homemade Tomato Soup (Low Carb)     0:30
# 5413  540945.0                             Sichuan Pepper Chicken     0:20
# 5414  541168.0                     D.A.M. Good Chicken Enchiladas     0:25
# 5415  541329.0  Rhonda&rsquo;s Imitation Doan&rsquo;s Curry Ch...     3:30
# 5416  541354.0           Chicken Pot Pie with Mashed Potato Crust      1:0
#
#      PrepTime TotalTime RecipeCategory  \
# ...

# %%
#all PrepTime
def strfdelta(tdelta, fmt):
    d = {"days": tdelta.days}
    d["hours"], rem = divmod(tdelta.seconds, 3600)
    d["minutes"], d["seconds"] = divmod(rem,60)
    day_in_hours= d["days"]*24
    d["hours"] = d["hours"] + day_in_hours
    return fmt.format(**d)
cook_time_list = chicken_list.loc[:, "PrepTime"]
for i, prep_time in enumerate(chicken_list['PrepTime']):
    new_prep_time = strfdelta(isodate.parse_duration(prep_time), '{hours}:{minutes}')
    chicken_list.at[i, 'PrepTime'] = new_prep_time
chicken_list
# Out:
#       RecipeId                                               Name CookTime  \
# 0         44.0                             Warm Chicken A La King      0:3
# 1         71.0                              Chicken and Dumplings     0:43
# 2        112.0                       Chicken and Broccoli Lasagna     0:55
# 3        150.0                      All-Purpose Crock Pot Chicken     8:40
# 4        162.0                                    Chicken Lasagna      2:0
# ...        ...                                                ...      ...
# 5412  540829.0                    Homemade Tomato Soup (Low Carb)     0:30
# 5413  540945.0                             Sichuan Pepper Chicken     0:20
# 5414  541168.0                     D.A.M. Good Chicken Enchiladas     0:25
# 5415  541329.0  Rhonda&rsquo;s Imitation Doan&rsquo;s Curry Ch...     3:30
# 5416  541354.0           Chicken Pot Pie with Mashed Potato Crust      1:0
#
#      PrepTime TotalTime RecipeCategory  \
# ...

# %%
#all total time 
def strfdelta(tdelta, fmt):
    d = {"days": tdelta.days}
    d["hours"], rem = divmod(tdelta.seconds, 3600)
    d["minutes"], d["seconds"] = divmod(rem,60)
    day_in_hours= d["days"]*24
    d["hours"] = d["hours"] + day_in_hours
    return fmt.format(**d)
cook_time_list = chicken_list.loc[:, "TotalTime"]
for i, total_time in enumerate(chicken_list['TotalTime']):
    new_total_time = strfdelta(isodate.parse_duration(total_time), '{hours}:{minutes}')
    chicken_list.at[i, 'TotalTime'] = new_total_time
chicken_list
# Out:
#       RecipeId                                               Name CookTime  \
# 0         44.0                             Warm Chicken A La King      0:3
# 1         71.0                              Chicken and Dumplings     0:43
# 2        112.0                       Chicken and Broccoli Lasagna     0:55
# 3        150.0                      All-Purpose Crock Pot Chicken     8:40
# 4        162.0                                    Chicken Lasagna      2:0
# ...        ...                                                ...      ...
# 5412  540829.0                    Homemade Tomato Soup (Low Carb)     0:30
# 5413  540945.0                             Sichuan Pepper Chicken     0:20
# 5414  541168.0                     D.A.M. Good Chicken Enchiladas     0:25
# 5415  541329.0  Rhonda&rsquo;s Imitation Doan&rsquo;s Curry Ch...     3:30
# 5416  541354.0           Chicken Pot Pie with Mashed Potato Crust      1:0
#
#      PrepTime TotalTime RecipeCategory  \
# ...

# %%
chicken_list.shape
chicken_list.isnull().sum()
# Out:
# RecipeId                 0
# Name                     0
# CookTime                 0
# PrepTime                 0
# TotalTime                0
# RecipeCategory           0
# Keywords                 0
# RecipeIngredientParts    0
# Calories                 0
# FatContent               0
# SaturatedFatContent      0
# CholesterolContent       0
# SodiumContent            0
# CarbohydrateContent      0
# FiberContent             0
# SugarContent             0
# ProteinContent           0
# RecipeInstructions       0
# dtype: int64

# %%
chicken_list.to_csv('/Users/brockberenato/Desktop/capstone - individual overview/chicken_ing_clean.csv')

# %%
ingredients = chicken_list[['RecipeIngredientParts','RecipeId']]
ingredients.to_csv('/Users/brockberenato/Desktop/capstone - individual overview/ingredients.csv',index=False )
